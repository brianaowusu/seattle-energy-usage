# %% [markdown]
# # Seattle Energy Usage

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import warnings
import os 
import sqlite3

# %%
conn = sqlite3.connect("energy.db")

df = pd.read_csv("/Users/bri/Downloads/seattle-energy-usage/data/Building_Energy_Benchmarking_Data,_2015-Present_20260416.csv")

df.to_sql("energy_cleaned", conn, if_exists="replace", index=False)

conn.close()
# Out:
# /var/folders/y2/rl2xxnnn5vs0rqbyqts6whnc0000gn/T/ipykernel_12186/2001972894.py:3: DtypeWarning: Columns (4,23,24,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/bri/Downloads/seattle-energy-usage/data/Building_Energy_Benchmarking_Data,_2015-Present_20260416.csv")
